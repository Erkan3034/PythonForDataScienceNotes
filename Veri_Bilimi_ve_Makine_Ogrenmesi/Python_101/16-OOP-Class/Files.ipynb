# %% [markdown]
# ## working with files

# %%
# %%writefile myFile.txt
# test1
# test2
# test3
# Out:
# Writing myFile.txt

# %%
myFile = open("myFile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.read() # ikinci oumad açıktı almadık, çüünkü "cursor" içeirğin en sonunda yani boş satıra geçti.Bu cursoru okuma işleminden sonra 0. konuma(yan mentin başına almamaız lazım)
# Out:
# ''

# %%
myFile.seek(0) # cursoru başa taşındı, şimdi tekrar okuyalım.
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
with open("myFile.txt", "w") as file2:
    file2.write("test 4 ")

# %%
with open ("myFile.txt" , "r") as file2:
    myContent = file2.read()

# %%
myContent
# Out:
# 'test 4 '

# %%
with open("myFile.txt", "a") as file2:
    file2.write("test 5 ")

# %%
with open ("myFile.txt" , "r") as file3:
    myContent = file3.read()

# %%
myContent
# Out:
# 'test 4 test 5 '
