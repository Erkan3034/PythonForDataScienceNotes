# %% [markdown]
# # Functions

# %%
my_name= "Erkan"

# %%
my_name
# Out:
# 'Erkan'

# %%
upper_name = my_name.upper()

# %%
upper_name
# Out:
# 'ERKAN'

# %%
# bunu fonksiyona dökelim

def make_upper(self):
    return self.upper()

# %%
make_upper("Erkan")
# Out:
# 'ERKAN'
