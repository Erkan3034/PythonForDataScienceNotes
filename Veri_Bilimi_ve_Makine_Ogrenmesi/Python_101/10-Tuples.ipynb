# %% [markdown]
# # TUPLES

# %%
# IMMUTABILITY -> değiştirilemez ,  eklenemez, silinemez

# %%
myList = [10,20,30,40,50]

# %%
myList
# Out:
# [10, 20, 30, 40, 50]

# %%
myList.append(60)

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
myList.pop(1) # 1. elemanı sil
# Out:
# 30

# %%
myList
# Out:
# [10, 30, 40, 50, 60]

# %%
#tuple

# %%
myTuple = (10,20,30,40)

# %%
myTuple.add(50) # değğiştiriliemez
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 myTuple.add(50)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
myTuple.remove(10) # silinemez
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 myTuple.remove(10)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
# değiştirmek, müdahale etmke istediğmizde tuple -> list. yaparızç.

# %%
tuple_can_change = list(myTuple)

# %%
type(tuple_can_change)
# Out:
# list

# %%
tuple_can_change.append(100)

# %%
tuple_can_change
# Out:
# [10, 20, 30, 40, 100]
