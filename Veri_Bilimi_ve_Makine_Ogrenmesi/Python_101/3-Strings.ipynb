# %% [markdown]
# # Strings

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "erkan"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Erkan'

# %%
x=12

# %%
type(x)
# Out:
# int

# %%
x.to_bytes()
# Out:
# b'\x0c'

# %%
x.is_integer()
# Out:
# True

# %% [markdown]
# ## String Methods

# %%
help(name)
# Out:
# No Python documentation found for 'erkan'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
name.count
# Out:
# <function str.count>

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("e")
# Out:
# 1

# %%
name.upper()
# Out:
# 'ERKAN'

# %%
name
# Out:
# 'erkan'

# %%
len(name)
# Out:
# 5
