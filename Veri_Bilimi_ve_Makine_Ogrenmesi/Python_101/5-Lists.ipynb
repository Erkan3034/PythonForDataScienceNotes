# %% [markdown]
# # Lists

# %%
name = "Erkan turgut"

# %%
name.split()
# Out:
# ['Erkan', 'turgut']

# %%
type(name.split())
# Out:
# list

# %% [markdown]
# ## ``list``

# %%
myString = "Hello World"

# %%
myString
# Out:
# 'Hello World'

# %%
myString[0]
# Out:
# 'H'

# %%
myString[0]="S"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 myString[0]="S"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ***==> String'ler immutable - immutability'dir. (değiştiriliemez)***

# %%
myList =[10,20,"Erkan"]

# %%
type(myList)

# %%
myList[2]

# %%
type(myList[0])

# %%
type(myList[2])

# %%
#listeler farklü türden veri alabilir.(str - int)

# %%
liste=[10,20,30,40,50,60,70,80]

# %%
liste[2] = 130

# %% [markdown]
#  ***==> Listeler, mutable, mutability(değiştirilebilir)***

# %%
#liste eleman sayısı:

len(liste)
# Out:
# 8

# %%
#listenin son elemanı:
print(liste[len(liste)-1])
# Out:
# 80

# %%
liste[-1] # aynı islem
# Out:
# 80

# %% [markdown]
# ## Liste Özellikleri

# %%
liste.append(1)

# %%
liste
# Out:
# [10, 20, 130, 40, 50, 60, 70, 1, 1]

# %%
liste=liste.copy()

# %%
liste2
# Out:
# [10, 20, 130, 40, 50, 60, 70, 80, 90]

# %%
liste.count(50) # 50'nin kaç kere geçtiğini bul
# Out:
# 1

# %%
help(liste.pop())
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %%
liste.pop() # son elemanı at
# Out:
# 1

# %%
liste.insert(5,10) #5. indexe ekle

# %%
liste
# Out:
# [10, 20, 130, 40, 50, 10, 10, 60, 70]

# %%
liste.remove(40) #seçili elamnı at

# %%
liste
# Out:
# [10, 20, 130, 50, 10, 10, 60, 70]

# %%
liste.reverse()

# %%
liste
# Out:
# [70, 60, 10, 10, 50, 130, 20, 10]

# %%
liste.sort()

# %%
liste
# Out:
# [10, 10, 10, 20, 50, 60, 70, 130]

# %%
del liste[0]       # 0. indexi siler

# %%
liste
# Out:
# [10, 10, 20, 50, 60, 70, 130]

# %%
liste2 = liste[1:4:] #Alt liste alma (slicing)

# %%
liste2
# Out:
# [10, 20, 50]

# %%
a = [1, 2]
b = [3, 4]
c = a + b   # [1,2,3,4]

# %%
c
# Out:
# [1, 2, 3, 4]

# %%
aranan = 50
if aranan in liste:
    print("Aranan eleman listede var: ", aranan)
# Out:
# Aranan eleman listede var:  50
