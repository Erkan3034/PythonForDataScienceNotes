# %% [markdown]
# # SET

# %% [markdown]
# - UNIQUE ELEMENTS
# - UNORDERED ELEMENTS

# %%
myList =[10,20,30,40,50,10,20,100,85,90,85]

# %%
len(myList)
# Out:
# 11

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 10, 20, 100, 85, 90, 85]

# %%
3
