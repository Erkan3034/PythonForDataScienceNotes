# %% [markdown]
# # SET

# %% [markdown]
# - UNIQUE ELEMENTS
# - UNORDERED ELEMENTS

# %%
myList =[10,20,30,40,50,10,20,100,85,90,85]

# %%
len(myList)
# Out:
# 11

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 10, 20, 100, 85, 90, 85]

# %%
# unique edelim:

# %%
mySet = set(myList)

# %%
mySet # tekrar eden elemanlardan sadece birer tane alır
# Out:
# {10, 20, 30, 40, 50, 85, 90, 100}

# %%
mySet2 = {30,40,50,110,120,80}

# %%
mySet.union(mySet2) # ikisini birlşetir
# Out:
# {10, 20, 30, 40, 50, 80, 85, 90, 100, 110, 120}

# %%
mySet.difference(mySet2) # mySet'te olup mySet2'de olmayanar.
# Out:
# {10, 20, 85, 90, 100}

# %%
mySet.intersection(mySet2) # KESISIMLERI AL.
# Out:
# {30, 40, 50}

# %%
emptySet = set()

# %%
emptySet.add(12)

# %%
emptySet
# Out:
# {12}

# %%
for i in emptySet:
    print(i)
# Out:
# 12

# %%
emptyDict = {}

# %%
type(emptyDict)
# Out:
# dict

# %%
emptyDict2 = dict()

# %%
type(emptyDict2)
# Out:
# dict

# %%
emptyDict2["apple"] = 150

# %%
emptyDict2
# Out:
# {'apple': 150}
